# %%
import string
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('Dataset.xlsx')
df
# Out:
#                                               Questions  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                 Answers
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# ...

# %%
df.isnull()
# Out:
#       Questions  Answers
# 0         False    False
# 1         False    False
# 2         False    False
# 3         False    False
# 4         False    False
# ...         ...      ...
# 3720      False    False
# 3721      False    False
# 3722      False    False
# 3723      False    False
# 3724      False    False
#
# [3725 rows x 2 columns]

# %%
df.head()
# Out:
#                              Questions  \
# 0               hi, how are you doing?
# 1        i'm fine. how about yourself?
# 2  i'm pretty good. thanks for asking.
# 3    no problem. so how have you been?
# 4     i've been great. what about you?
#
#                                     Answers
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.

# %%
df.isnull().sum()
# Out:
# Questions    0
# Answers      0
# dtype: int64

# %%
df.nunique()
# Out:
# Questions    3510
# Answers      3512
# dtype: int64

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df['Questions'] = df['Questions'].apply(str.lower)
df['Answers'] = df['Answers'].apply(str.lower)

# %%
df2=df['Questions']
df2.head()
# Out:
# 0                 hi, how are you doing?
# 1          i'm fine. how about yourself?
# 2    i'm pretty good. thanks for asking.
# 3      no problem. so how have you been?
# 4       i've been great. what about you?
# Name: Questions, dtype: object

# %%
import nltk
nltk.download('punkt_tab')
tokens1 = word_tokenize(df2[0])
print(tokens1)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['hi', ',', 'how', 'are', 'you', 'doing', '?']

# %%
for i in range(3725):
  tokens1 = word_tokenize(df2[i])
  print(tokens1)
# Out:
# ['hi', ',', 'how', 'are', 'you', 'doing', '?']
# ['i', "'m", 'fine', '.', 'how', 'about', 'yourself', '?']
# ['i', "'m", 'pretty', 'good', '.', 'thanks', 'for', 'asking', '.']
# ['no', 'problem', '.', 'so', 'how', 'have', 'you', 'been', '?']
# ['i', "'ve", 'been', 'great', '.', 'what', 'about', 'you', '?']
# ['i', "'ve", 'been', 'good', '.', 'i', "'m", 'in', 'school', 'right', 'now', '.']
# ['what', 'school', 'do', 'you', 'go', 'to', '?']
# ['i', 'go', 'to', 'pcc', '.']
# ['do', 'you', 'like', 'it', 'there', '?']
# ['it', "'s", 'okay', '.', 'it', "'s", 'a', 'really', 'big', 'campus', '.']
# ['good', 'luck', 'with', 'school', '.']
# ['how', "'s", 'it', 'going', '?']
# ['i', "'m", 'doing', 'well', '.', 'how', 'about', 'you', '?']
# ['never', 'better', ',', 'thanks', '.']
# ['so', 'how', 'have', 'you', 'been', 'lately', '?']
# ['i', "'ve", 'actually', 'been', 'pretty', 'good', '.', 'you', '?']
# ['i', "'m", 'actually', 'in', 'school', 'right', 'now', '.']
# ...

# %%
df3=df['Answers']
df3.head()
# Out:
# 0               i'm fine. how about yourself?
# 1         i'm pretty good. thanks for asking.
# 2           no problem. so how have you been?
# 3            i've been great. what about you?
# 4    i've been good. i'm in school right now.
# Name: Answers, dtype: object

# %%
df3[0]
tokens2 = word_tokenize(df3[0])
print(tokens2)
# Out:
# ['i', "'m", 'fine', '.', 'how', 'about', 'yourself', '?']

# %%
for i in range(3725):
  tokens2 = word_tokenize(df3[i])
  print(tokens2)
# Out:
# ['i', "'m", 'fine', '.', 'how', 'about', 'yourself', '?']
# ['i', "'m", 'pretty', 'good', '.', 'thanks', 'for', 'asking', '.']
# ['no', 'problem', '.', 'so', 'how', 'have', 'you', 'been', '?']
# ['i', "'ve", 'been', 'great', '.', 'what', 'about', 'you', '?']
# ['i', "'ve", 'been', 'good', '.', 'i', "'m", 'in', 'school', 'right', 'now', '.']
# ['what', 'school', 'do', 'you', 'go', 'to', '?']
# ['i', 'go', 'to', 'pcc', '.']
# ['do', 'you', 'like', 'it', 'there', '?']
# ['it', "'s", 'okay', '.', 'it', "'s", 'a', 'really', 'big', 'campus', '.']
# ['good', 'luck', 'with', 'school', '.']
# ['thank', 'you', 'very', 'much', '.']
# ['i', "'m", 'doing', 'well', '.', 'how', 'about', 'you', '?']
# ['never', 'better', ',', 'thanks', '.']
# ['so', 'how', 'have', 'you', 'been', 'lately', '?']
# ['i', "'ve", 'actually', 'been', 'pretty', 'good', '.', 'you', '?']
# ['i', "'m", 'actually', 'in', 'school', 'right', 'now', '.']
# ['which', 'school', 'do', 'you', 'attend', '?']
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df['Questions'] = df['Questions'].apply(str.lower)
df['Answers'] = df['Answers'].apply(str.lower)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df["Questions"] = df['Questions'].str.replace('[^\w\s]','')
df["Answers"] = df['Answers'].str.replace('[^\w\s]','')

# %%
df.head()
# Out:
#                              Questions  \
# 0               hi, how are you doing?
# 1        i'm fine. how about yourself?
# 2  i'm pretty good. thanks for asking.
# 3    no problem. so how have you been?
# 4     i've been great. what about you?
#
#                                     Answers
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.

# %%
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
def stop_word_removal(text):
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text
df['Questions'] = df['Questions'].apply(stop_word_removal)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.head()
# Out:
#                          Questions                                   Answers
# 0                       hi, doing?             i'm fine. how about yourself?
# 1              i'm fine. yourself?       i'm pretty good. thanks for asking.
# 2  i'm pretty good. thanks asking.         no problem. so how have you been?
# 3                   problem. been?          i've been great. what about you?
# 4                 i've great. you?  i've been good. i'm in school right now.

# %%
df.head(20)
# Out:
#                            Questions  \
# 0                         hi, doing?
# 1                i'm fine. yourself?
# 2    i'm pretty good. thanks asking.
# 3                     problem. been?
# 4                   i've great. you?
# 5   i've good. i'm school right now.
# 6                      school go to?
# 7                            go pcc.
# 8                        like there?
# 9           okay. really big campus.
# 10                 good luck school.
# 11                      how's going?
# 12                    i'm well. you?
# 13             never better, thanks.
# 14                           lately?
# 15   i've actually pretty good. you?
# 16    i'm actually school right now.
# 17                    school attend?
# 18      i'm attending pcc right now.
# 19                   enjoying there?
#
#                                            Answers
# 0                    i'm fine. how about yourself?
# 1              i'm pretty good. thanks for asking.
# ...

# %%
stop_words1 = set(stopwords.words('english'))
print(stop_words1)
filtered_tokens1 = [word for word in df2 if word.islower() not in stop_words1]
print(filtered_tokens1)
# Out:
# {'yourself', "isn't", 'i', 'same', 'd', 'there', "don't", "hadn't", 'itself', 'not', 'couldn', "aren't", 'out', 'just', 'each', 'or', 'mightn', 'are', 'what', 'so', 'mustn', 'she', 'until', 'myself', 'down', 'was', 'once', 'shan', 'this', "wouldn't", 'while', 'whom', 'above', 'because', 'very', 'any', 'after', 'such', 'being', 'be', 're', 'm', 'with', 'isn', 'to', 'during', 'about', 'own', 'before', 'here', 'has', 'some', 'shouldn', 'an', 'off', 'doing', 'how', 'at', "you'd", 'should', 'most', 'didn', "didn't", 'needn', 'no', "shouldn't", 'can', 'hadn', "won't", 'against', 'his', 'in', 'we', 'if', 'hers', 'is', 'haven', "it's", 'been', 'ain', "weren't", 'who', "couldn't", "wasn't", 'now', 'were', 'wouldn', "doesn't", 'over', 'it', 'all', 'more', 'y', 'my', 'only', 'than', 'them', 'for', 'had', 'further', 've', 'other', 'but', 't', "she's", 'and', 'yours', 's', 'me', "you've", 'when', 'do', 'through', 'don', 'am', 'herself', 'under', "hasn't", 'nor', "mightn't", 'into', 'on', "haven't
# ...

# %%
stop_words2 = set(stopwords.words('english'))
print(stop_words2)
filtered_tokens2 = [word for word in df3 if word.islower() not in stop_words2]
print(filtered_tokens2)
# Out:
# {'yourself', "isn't", 'i', 'same', 'd', 'there', "don't", "hadn't", 'itself', 'not', 'couldn', "aren't", 'out', 'just', 'each', 'or', 'mightn', 'are', 'what', 'so', 'mustn', 'she', 'until', 'myself', 'down', 'was', 'once', 'shan', 'this', "wouldn't", 'while', 'whom', 'above', 'because', 'very', 'any', 'after', 'such', 'being', 'be', 're', 'm', 'with', 'isn', 'to', 'during', 'about', 'own', 'before', 'here', 'has', 'some', 'shouldn', 'an', 'off', 'doing', 'how', 'at', "you'd", 'should', 'most', 'didn', "didn't", 'needn', 'no', "shouldn't", 'can', 'hadn', "won't", 'against', 'his', 'in', 'we', 'if', 'hers', 'is', 'haven', "it's", 'been', 'ain', "weren't", 'who', "couldn't", "wasn't", 'now', 'were', 'wouldn', "doesn't", 'over', 'it', 'all', 'more', 'y', 'my', 'only', 'than', 'them', 'for', 'had', 'further', 've', 'other', 'but', 't', "she's", 'and', 'yours', 's', 'me', "you've", 'when', 'do', 'through', 'don', 'am', 'herself', 'under', "hasn't", 'nor', "mightn't", 'into', 'on', "haven't
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens1 = [lemmatizer.lemmatize(word) for word in filtered_tokens1]
print(lemmatized_tokens1)
# Out:
# ['hi, how are you doing?', "i'm fine. how about yourself?", "i'm pretty good. thanks for asking.", 'no problem. so how have you been?', "i've been great. what about you?", "i've been good. i'm in school right now.", 'what school do you go to?', 'i go to pcc.', 'do you like it there?', "it's okay. it's a really big campus.", 'good luck with school.', "how's it going?", "i'm doing well. how about you?", 'never better, thanks.', 'so how have you been lately?', "i've actually been pretty good. you?", "i'm actually in school right now.", 'which school do you attend?', "i'm attending pcc right now.", 'are you enjoying it there?', "it's not bad. there are a lot of people there.", 'good luck with that.', 'how are you doing today?', "i'm doing great. what about you?", "i'm absolutely lovely, thank you.", "everything's been good with you?", "i haven't been better. how about yourself?", 'i started school recently.', 'where are you going to school?', "i'm going to pcc.", 'how do you like it so f
# ...

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens2 = [lemmatizer.lemmatize(word) for word in filtered_tokens2]
print(lemmatized_tokens2)
# Out:
# ["i'm fine. how about yourself?", "i'm pretty good. thanks for asking.", 'no problem. so how have you been?', "i've been great. what about you?", "i've been good. i'm in school right now.", 'what school do you go to?', 'i go to pcc.', 'do you like it there?', "it's okay. it's a really big campus.", 'good luck with school.', 'thank you very much.', "i'm doing well. how about you?", 'never better, thanks.', 'so how have you been lately?', "i've actually been pretty good. you?", "i'm actually in school right now.", 'which school do you attend?', "i'm attending pcc right now.", 'are you enjoying it there?', "it's not bad. there are a lot of people there.", 'good luck with that.', 'thanks.', "i'm doing great. what about you?", "i'm absolutely lovely, thank you.", "everything's been good with you?", "i haven't been better. how about yourself?", 'i started school recently.', 'where are you going to school?', "i'm going to pcc.", 'how do you like it so far?', 'i like it so far. my classes ar
# ...

# %%
stemmer = PorterStemmer()
stemmed_tokens1  = [stemmer.stem(word) for word in filtered_tokens1]
stemmed_tokens1
# Out:
# ['hi, how are you doing?',
#  "i'm fine. how about yourself?",
#  "i'm pretty good. thanks for asking.",
#  'no problem. so how have you been?',
#  "i've been great. what about you?",
#  "i've been good. i'm in school right now.",
#  'what school do you go to?',
#  'i go to pcc.',
#  'do you like it there?',
#  "it's okay. it's a really big campus.",
#  'good luck with school.',
#  "how's it going?",
#  "i'm doing well. how about you?",
#  'never better, thanks.',
#  'so how have you been lately?',
#  "i've actually been pretty good. you?",
#  "i'm actually in school right now.",
#  'which school do you attend?',
#  "i'm attending pcc right now.",
#  'are you enjoying it there?',
#  "it's not bad. there are a lot of people there.",
#  'good luck with that.',
#  'how are you doing today?',
#  "i'm doing great. what about you?",
#  "i'm absolutely lovely, thank you.",
#  "everything's been good with you?",
#  "i haven't been better. how about yourself?",
# ...

# %%
stemmer = PorterStemmer()
stemmed_tokens2  = [stemmer.stem(word) for word in filtered_tokens2]
stemmed_tokens2
# Out:
# ["i'm fine. how about yourself?",
#  "i'm pretty good. thanks for asking.",
#  'no problem. so how have you been?',
#  "i've been great. what about you?",
#  "i've been good. i'm in school right now.",
#  'what school do you go to?',
#  'i go to pcc.',
#  'do you like it there?',
#  "it's okay. it's a really big campus.",
#  'good luck with school.',
#  'thank you very much.',
#  "i'm doing well. how about you?",
#  'never better, thanks.',
#  'so how have you been lately?',
#  "i've actually been pretty good. you?",
#  "i'm actually in school right now.",
#  'which school do you attend?',
#  "i'm attending pcc right now.",
#  'are you enjoying it there?',
#  "it's not bad. there are a lot of people there.",
#  'good luck with that.',
#  'thanks.',
#  "i'm doing great. what about you?",
#  "i'm absolutely lovely, thank you.",
#  "everything's been good with you?",
#  "i haven't been better. how about yourself?",
#  'i started school recently.',
#  'where are you going to school?',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
count_vectorizer = CountVectorizer()
tfidf_transformer = TfidfTransformer()

# %%
X_counts = count_vectorizer.fit_transform(df['Questions'])
print(X_counts)
# Out:
#   (0, 912)	1
#   (0, 573)	1
#   (1, 725)	1
#   (1, 2273)	1
#   (2, 1505)	1
#   (2, 839)	1
#   (2, 1995)	1
#   (2, 133)	1
#   (3, 1511)	1
#   (3, 196)	1
#   (4, 2129)	1
#   (4, 851)	1
#   (4, 2270)	1
#   (5, 839)	1
#   (5, 2129)	1
#   (5, 1675)	1
#   (5, 1616)	1
#   (5, 1316)	1
#   (6, 1675)	1
#   (6, 830)	1
#   (6, 2042)	1
#   (7, 830)	1
#   (7, 1403)	1
#   (8, 1125)	1
#   (8, 2003)	1
#   :	:
#   (3718, 1340)	1
#   (3718, 65)	1
#   (3719, 967)	1
#   (3719, 1340)	1
#   (3719, 65)	1
#   (3719, 874)	1
#   (3720, 839)	1
#   (3720, 1996)	1
#   (3720, 1200)	1
#   (3720, 1538)	1
#   (3720, 1340)	1
#   (3720, 65)	1
#   (3721, 1616)	1
#   (3721, 872)	1
#   (3722, 2265)	1
#   (3722, 1121)	1
#   (3723, 1616)	1
#   (3723, 1261)	1
#   (3723, 2183)	1
#   (3723, 1894)	1
#   (3723, 2120)	1
#   (3723, 871)	1
#   (3724, 1616)	1
#   (3724, 2250)	1
#   (3724, 871)	1

# %%
X_tfidf = tfidf_transformer.fit_transform(X_counts)
print(X_tfidf)
# Out:
#   (0, 573)	0.6541141259067235
#   (0, 912)	0.7563958687679904
#   (1, 725)	0.715623259064211
#   (1, 2273)	0.6984864716559062
#   (2, 133)	0.5834758526204609
#   (2, 839)	0.36867172714045904
#   (2, 1505)	0.48141094670765233
#   (2, 1995)	0.5402597406860327
#   (3, 196)	0.8119634301235921
#   (3, 1511)	0.5837083074121272
#   (4, 851)	0.6200889216542635
#   (4, 2129)	0.5906919270363581
#   (4, 2270)	0.5163068628013059
#   (5, 839)	0.3868344001320192
#   (5, 1316)	0.5121425354524831
#   (5, 1616)	0.4343276484670563
#   (5, 1675)	0.45024836202489343
#   (5, 2129)	0.44351446033447495
#   (6, 830)	0.468168714554127
#   (6, 1675)	0.5732218459236167
#   (6, 2042)	0.6724840296011928
#   (7, 830)	0.4871141589759176
#   (7, 1403)	0.8733383056554799
#   (8, 1125)	0.5958078923312419
#   (8, 2003)	0.803126985871975
#   :	:
#   (3718, 1340)	0.512573987149627
#   (3718, 2009)	0.3896506403096328
#   (3719, 65)	0.5359950823450087
#   (3719, 874)	0.5491452780191893
#   (3719, 967)	0.4802276870772139
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
classifier = DecisionTreeClassifier()
classifier1 = MultinomialNB()
classifier.fit(X_tfidf, df['Answers'])
# Out:
# DecisionTreeClassifier()

# %%
def predict_answer(t):
  t=t.lower()
  t=t.replace('[^\w\s]','')
  t = ' '.join(word for word in t.split() if word not in stop_words)
  t2 = tfidf_transformer.transform(count_vectorizer.transform([t]))
  predicted_answer = classifier.predict(t2)
  return predicted_answer

# %%
while True:
    input_question = input("Enter your question")
    if input_question.lower() == 'exit':
        print("Exiting the program.")
        break
    predicted_answer = predict_answer(input_question)
    print("Predicted Answer:", predicted_answer)
